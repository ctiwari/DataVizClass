# %%
# %pip install psycopg2-binary
# %pip install geopandas
# %pip install mapclassify
# %pip install branca
# %pip install folium
# Out:
# Requirement already satisfied: psycopg2-binary in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (2.9.10)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: geopandas in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from geopandas) (2.2.3)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from geopandas) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from geopandas) (2.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from pandas>=1.4.0->geopandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from pandas>=1.4.0->geopandas) (2025.1)
# Requirement already satisfied: certifi in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from pyogrio>=0.7.2->geopandas) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: mapclassify in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (2.8.1)
# Requirement already satisfied: networkx>=2.7 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from mapclassify) (3.4.2)
# Requirement already satisfied: numpy>=1.23 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from mapclassify) (2.2.3)
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from mapclassify) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.0 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from mapclassify) (1.6.1)
# Requirement already satisfied: scipy>=1.8 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from mapclassify) (1.15.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from scikit-learn>=1.0->mapclassify) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from scikit-learn>=1.0->mapclassify) (3.5.0)
# Requirement already satisfied: six>=1.5 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas!=1.5.0,>=1.4->mapclassify) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: branca in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (0.8.1)
# Requirement already satisfied: jinja2>=3 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from branca) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from jinja2>=3->branca) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: folium in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (0.19.5)
# Requirement already satisfied: branca>=0.6.0 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from folium) (2.2.3)
# Requirement already satisfied: requests in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from folium) (2025.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from requests->folium) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from requests->folium) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages (from requests->folium) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2
import geopandas as gpd

# Create connection to database
conn = psycopg2.connect(
    dbname="cosea_db",  # Database name
    user="cosea_user",  # Database user
    password="CoSeaIndex",  # Database password
    host="pgsql.dataconn.net",  # Database host
    port="5432"  # Database port
)

# Select data from table into geopandas data frame
query = "SELECT cbgpolygeom as geom FROM \"2024\".tbl_cbg limit 100"
gdf = gpd.GeoDataFrame.from_postgis(query, conn, geom_col='geom')
gdf.explore()
# Out:
# /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages/geopandas/io/sql.py:185: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(
# /home/ctiwari/Documents/CodeRepos/DataVizClass/.venv/lib/python3.12/site-packages/geopandas/io/sql.py:473: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(spatial_ref_sys_sql, con)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1209fd5c57b358f97716ef788a71f4ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1209fd5c57b358f97716ef788a71f4ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1209fd5c57b358f97716ef788a71f4ec = L.map(
#                 &quot;map_1209fd5c57b358f97716ef788a71f4ec&quot;,
#                 {
#                     center: [32.74844549999786, -83.06020050000039],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_1209fd5c57b358f97716ef788a71f4ec);
#
#
#
#
#
#             var tile_layer_5956f15fcc7a03ca0d95c80e8e11ed73 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5956f15fcc7a03ca0d95c80e8e11ed73.addTo(map_1209fd5c57b358f97716ef788a71f4ec);
#
#
#             map_1209fd5c57b358f97716ef788a71f4ec.fitBounds(
#                 [[30.828138999997506, -84.9820770000003], [34.6687519999982, -81.13832400000048]],
#                 {}
#             );
#
#
#         function geo_json_9dddf83d69ef318df3aa824d2e1ae99e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_9dddf83d69ef318df3aa824d2e1ae99e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_9dddf83d69ef318df3aa824d2e1ae99e_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_9dddf83d69ef318df3aa824d2e1ae99e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_9dddf83d69ef318df3aa824d2e1ae99e_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_9dddf83d69ef318df3aa824d2e1ae99e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_9dddf83d69ef318df3aa824d2e1ae99e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_9dddf83d69ef318df3aa824d2e1ae99e = L.geoJson(null, {
#                 onEachFeature: geo_json_9dddf83d69ef318df3aa824d2e1ae99e_onEachFeature,
#
#                 style: geo_json_9dddf83d69ef318df3aa824d2e1ae99e_styler,
#                 pointToLayer: geo_json_9dddf83d69ef318df3aa824d2e1ae99e_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_9dddf83d69ef318df3aa824d2e1ae99e_add (data) {
#             geo_json_9dddf83d69ef318df3aa824d2e1ae99e
#                 .addData(data);
#         }
#             geo_json_9dddf83d69ef318df3aa824d2e1ae99e_add({&quot;bbox&quot;: [-84.9820770000003, 30.828138999997506, -81.13832400000048, 34.6687519999982], &quot;features&quot;: [{&quot;bbox&quot;: [-81.73965000000041, 32.284826999997634, -81.60373400000043, 32.38397799999763], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-81.73965000000041, 32.34394399999762], [-81.73398600000043, 32.343077999997625], [-81.73364800000043, 32.343042999997635], [-81.73326600000043, 32.34304599999764], [-81.7330600000004, 32.34306299999763], [-81.73284400000043, 32.34307199999764], [-81.73242400000042, 32.343155999997634], [-81.73185800000041, 32.34340599999763], [-81.73152700000043, 32.34356299999764], [-81.73103100000041, 32.34377699999763], [-81.72950500000043, 32

# %%
import psycopg2
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Create connection to database
conn = psycopg2.connect(
    dbname="cosea_db",  # Database name
    user="cosea_user",  # Database user
    password="CoSeaIndex",  # Database password
    host="pgsql.dataconn.net",  # Database host
    port="5432"  # Database port
)

# Select data from table into geopandas data frame
query = "SELECT * from \"2024\".tempasiannocomp"
df = pd.read_sql(query, conn)


# INCLASS
sns_plot = sns.violinplot(x="prop_nocomputer",  hue="di_asian_cat", split=True, inner="quart", gap=.1, data=df)
#sns.histplot(data=df, x="prop_nocomputer", hue="di_asian_cat", bins=30, kde=False, element="step", stat="count")
# Out:
# /tmp/ipykernel_11665/1389531962.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
